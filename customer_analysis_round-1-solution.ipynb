# %%
# Cust Analysis round 1- LAB Case Study

# %%
import numpy as np

# %%
import pandas as pd

# %%
# Read the three files into python as dataframes

# %%
file1 = pd.read_csv('file1.csv')

# %%
file2 = pd.read_csv('/Users/Lenovo/Desktop/file2.csv')

# %%
file3 = pd.read_csv('/Users/Lenovo/Desktop/file3.csv')

# %%
# Show the DataFrame's shape

# %%
file1.shape
# Out:
# (1007, 17)

# %%
file2.shape
# Out:
# (996, 11)

# %%
file3.shape
# Out:
# (7070, 11)

# %%
# Standardize header names.

# %%
file1.columns.to_list()
# Out:
# ['CONTROLN',
#  'STATE',
#  'GENDER',
#  'HV1',
#  'IC1',
#  'IC4',
#  'HVP1',
#  'IC5',
#  'POBC1',
#  'POBC2',
#  'IC2',
#  'IC3',
#  'AVGGIFT',
#  'TCODE',
#  'DOB',
#  'DOMAIN',
#  'TARGET_D']

# %%
cols = []
for i in range (len(file1.columns)):
    cols.append(file1.columns[i].lower())
cols
# Out:
# ['controln',
#  'state',
#  'gender',
#  'hv1',
#  'ic1',
#  'ic4',
#  'hvp1',
#  'ic5',
#  'pobc1',
#  'pobc2',
#  'ic2',
#  'ic3',
#  'avggift',
#  'tcode',
#  'dob',
#  'domain',
#  'target_d']

# %%
# Concatenate the three dataframes

data_all = pd.concat([file1,file2,file3],axis=0)

# %%
data_all.shape
# Out:
# (9073, 29)

# %%
data_all.head()
# Out:
#    CONTROLN STATE GENDER      HV1    IC1    IC4  HVP1    IC5  POBC1  POBC2  \
# 0   44060.0    FL      M   AAA896  392.0  520.0   7.0  21975    6.0   16.0
# 1   96093.0    IL      M   537.00  365.0  473.0   0.0  19387    1.0   89.0
# 2   43333.0    FL      F   725.00  301.0  436.0   3.0  18837   11.0   17.0
# 3   21885.0    NC      M  AAA1095  401.0  413.0   7.0  14014    1.0   74.0
# 4  190108.0    FL      F   995.00  252.0  348.0   0.0  17991    5.0    6.0
#
#    ...  Education  Customer Lifetime Value  Income  Monthly Premium Auto  \
# 0  ...        NaN                      NaN     NaN                   NaN
# 1  ...        NaN                      NaN     NaN                   NaN
# 2  ...        NaN                      NaN     NaN                   NaN
# 3  ...        NaN                      NaN     NaN                   NaN
# 4  ...        NaN                      NaN     NaN                   NaN
#
# ...

# %%
data_all = data_all.reset_index(drop=True)

# %%
data_all
# Out:
#       CONTROLN STATE GENDER      HV1    IC1    IC4  HVP1    IC5  POBC1  POBC2  \
# 0      44060.0    FL      M   AAA896  392.0  520.0   7.0  21975    6.0   16.0
# 1      96093.0    IL      M   537.00  365.0  473.0   0.0  19387    1.0   89.0
# 2      43333.0    FL      F   725.00  301.0  436.0   3.0  18837   11.0   17.0
# 3      21885.0    NC      M  AAA1095  401.0  413.0   7.0  14014    1.0   74.0
# 4     190108.0    FL      F   995.00  252.0  348.0   0.0  17991    5.0    6.0
# ...        ...   ...    ...      ...    ...    ...   ...    ...    ...    ...
# 9068       NaN   NaN    NaN      NaN    NaN    NaN   NaN    NaN    NaN    NaN
# 9069       NaN   NaN    NaN      NaN    NaN    NaN   NaN    NaN    NaN    NaN
# 9070       NaN   NaN    NaN      NaN    NaN    NaN   NaN    NaN    NaN    NaN
# 9071       NaN   NaN    NaN      NaN    NaN    NaN   NaN    NaN    NaN    NaN
# 9072       NaN   NaN    NaN      NaN    NaN    NaN   NaN    NaN    NaN    NaN
#
# ...

# %%
# Which columns are numerical?

data_all._get_numeric_data()
# Out:
#       CONTROLN    IC1    IC4  HVP1  POBC1  POBC2    IC2    IC3    AVGGIFT  \
# 0      44060.0  392.0  520.0   7.0    6.0   16.0  430.0  466.0  28.000000
# 1      96093.0  365.0  473.0   0.0    1.0   89.0  415.0  410.0   5.666667
# 2      43333.0  301.0  436.0   3.0   11.0   17.0  340.0  361.0   4.111111
# 3      21885.0  401.0  413.0   7.0    1.0   74.0  407.0  399.0  27.277778
# 4     190108.0  252.0  348.0   0.0    5.0    6.0  280.0  316.0   6.000000
# ...        ...    ...    ...   ...    ...    ...    ...    ...        ...
# 9068       NaN    NaN    NaN   NaN    NaN    NaN    NaN    NaN        NaN
# 9069       NaN    NaN    NaN   NaN    NaN    NaN    NaN    NaN        NaN
# 9070       NaN    NaN    NaN   NaN    NaN    NaN    NaN    NaN        NaN
# 9071       NaN    NaN    NaN   NaN    NaN    NaN    NaN    NaN        NaN
# 9072       NaN    NaN    NaN   NaN    NaN    NaN    NaN    NaN        NaN
#
#       TCODE     DOB  TARGET_D   Income  Monthly Premium Auto  \
# ...

# %%
data_num = data_all._get_numeric_data()

# %%
# Which columns are categorical?

data_cat = data_all.drop(columns=data_num.columns)

# %%
data_cat
# Out:
#      STATE GENDER      HV1    IC5 DOMAIN Customer   ST Education  \
# 0       FL      M   AAA896  21975     C2      NaN  NaN       NaN
# 1       IL      M   537.00  19387     T2      NaN  NaN       NaN
# 2       FL      F   725.00  18837     C2      NaN  NaN       NaN
# 3       NC      M  AAA1095  14014     T2      NaN  NaN       NaN
# 4       FL      F   995.00  17991     C2      NaN  NaN       NaN
# ...    ...    ...      ...    ...    ...      ...  ...       ...
# 9068   NaN    NaN      NaN    NaN    NaN  LA72316  NaN  Bachelor
# 9069   NaN    NaN      NaN    NaN    NaN  PK87824  NaN   College
# 9070   NaN    NaN      NaN    NaN    NaN  TD14365  NaN  Bachelor
# 9071   NaN    NaN      NaN    NaN    NaN  UP19263  NaN   College
# 9072   NaN    NaN      NaN    NaN    NaN  Y167826  NaN   College
#
#      Customer Lifetime Value Number of Open Complaints     Policy Type  \
# 0                        NaN                       NaN             NaN
# ...

# %%
# Understand the meaning of all columns

# %%
# Perform the data cleaning operations mentioned so far in class

data_num 
data_cat

# %%
# Delete the column education and the number of open complaints from the dataframe.

# %%
data_all.columns
# Out:
# Index(['CONTROLN', 'STATE', 'GENDER', 'HV1', 'IC1', 'IC4', 'HVP1', 'IC5',
#        'POBC1', 'POBC2', 'IC2', 'IC3', 'AVGGIFT', 'TCODE', 'DOB', 'DOMAIN',
#        'TARGET_D', 'Customer', 'ST', 'Education', 'Customer Lifetime Value',
#        'Income', 'Monthly Premium Auto', 'Number of Open Complaints',
#        'Total Claim Amount', 'Policy Type', 'Vehicle Class', 'State',
#        'Gender'],
#       dtype='object')

# %%
data_all = data.drop(['Education','Number of Open Complaints'], axis=1)

# %%
data_all.columns
# Out:
# Index(['CONTROLN', 'STATE', 'GENDER', 'HV1', 'IC1', 'IC4', 'HVP1', 'IC5',
#        'POBC1', 'POBC2', 'IC2', 'IC3', 'AVGGIFT', 'TCODE', 'DOB', 'DOMAIN',
#        'TARGET_D', 'Customer', 'ST', 'Customer Lifetime Value', 'Income',
#        'Monthly Premium Auto', 'Total Claim Amount', 'Policy Type',
#        'Vehicle Class', 'State', 'Gender'],
#       dtype='object')

# %% [raw]
# Some column names are not consistently in lower or upper case and also seperated by whitespaces

# %%
def standardize_col(col):
    return col.lower().replace(" ", "_")

# %%
cols = []
for i in range (len(data_all.columns)):
    cols.append(data_all.columns[i].lower())
cols
# Out:
# ['controln',
#  'state',
#  'gender',
#  'hv1',
#  'ic1',
#  'ic4',
#  'hvp1',
#  'ic5',
#  'pobc1',
#  'pobc2',
#  'ic2',
#  'ic3',
#  'avggift',
#  'tcode',
#  'dob',
#  'domain',
#  'target_d',
#  'customer',
#  'st',
#  'customer lifetime value',
#  'income',
#  'monthly premium auto',
#  'total claim amount',
#  'policy type',
#  'vehicle class',
#  'state',
#  'gender']

# %%
standardize_col("Total Claim Amount")
# Out:
# 'total_claim_amount'

# %%
for col in data_all.columns.to_list():
    print(standardize_col(col))
# Out:
# controln
# state
# gender
# hv1
# ic1
# ic4
# hvp1
# ic5
# pobc1
# pobc2
# ic2
# ic3
# avggift
# tcode
# dob
# domain
# target_d
# customer
# st
# customer_lifetime_value
# income
# monthly_premium_auto
# total_claim_amount
# policy_type
# vehicle_class
# state
# gender

# %%
# Correct the values in the column customer lifetime value. They are given as a percent, so multiply them by 100 and change dtype to numerical type.

# %%
data_cat['customer_lifetime_value'].value_counts()

def clean_clv(x):
    return float(str(x).replace('%', ''))*100

data_cat['customer_lifetime_value'] = data_cat['customer_lifetime_value'].apply(clean_clv)

# %%
# Check for duplicate rows in the data and remove if any.

# %%
data_all = data_all.drop_duplicates()

# %%
# Filter out the data for customers who have an income of 0 or less.

# %%
data_all.query('income >= 0')
